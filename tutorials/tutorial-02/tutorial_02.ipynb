# %% [markdown]
# # Tutorial 02
# - Practice basic data handling using Python.
# - Practice data pre-processing using Pandas.
# - Generate basic plots.

# %% [markdown]
# ## Exercise 01
# Consider the dataset police.csv from traffic stops by police officers in the state of Idaho. Other states data can be found from `https://openpolicing.stanford.edu/`. Download the dataset from Blackboard. Use Python to perform the following tasks:
#
# 1. Load the data into a dataframe and print its first 10 rows.
# 2. Show a summary of all missing values.
# 3. Drop the column county name.
# 4. Drop the rows that have missing values.
# 5. Show the data types of the columns’s data.
# 6. Show a summary statistics of the data.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base_path = '~/Developer/UoL/big-data-and-predictive-analytics/tutorials/tutorial-02/'

df_data = pd.read_csv(base_path + 'police.csv')
df_data.head(10)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 3
#       1 base_path = '~/Developer/UoL/big-data-and-predictive-analytics/tutorials/tutorial-02/'
# ----> 3 df_data = pd.read_csv(base_path + 'police.csv')
#       4 df_data.head(10)
#
# ...
