# %%
# Imports

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_path = '~/Developer/UoL/big-data-and-predictive-analytics/labs/lab_03/'

advertising_data = pd.read_csv(base_path + 'advertising.csv')
automobile_price_data = pd.read_csv(base_path + 'Automobile_price_data_Raw.csv')
cruise_data = pd.read_csv(base_path + 'cruise.csv')

# %%
automobile_price_data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
automobile_price_data.replace("?", np.nan, inplace=True)

# %%
cols = ['price', 'bore', 'stroke', 'horsepower', 'peak-rpm']

# %%
automobile_price_data[cols] = automobile_price_data[cols].apply(pd.to_numeric, errors = 'coerce')

# %%
automobile_price_data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
data_cleaned['lnprice'] = np.log(data_cleaned['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data_cleaned['lnprice'] = np.log(data_cleaned['price'])
#
# NameError: name 'data_cleaned' is not defined

# %%
data_cleaned
